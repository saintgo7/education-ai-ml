# %% [markdown]
# # 이미지 복원 (Inpainting)
#
# **목표**: 손상된 이미지 복원
# **데이터**: Images
# **소요시간**: 3주

# %% [markdown]
# ## 1. 환경 설정
# 필요한 라이브러리와 데이터를 준비합니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print('프로젝트 환경 준비 완료')
