# %% [markdown]
# # 멀티 에이전트 협력
#
# **목표**: 다중 에이전트 구성
# **데이터**: Multi-agent Environment
# **소요시간**: 4주

# %% [markdown]
# ## 1. 환경 설정
# 필요한 라이브러리와 데이터를 준비합니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print('프로젝트 환경 준비 완료')
