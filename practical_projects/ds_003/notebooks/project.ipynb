# %% [markdown]
# # 신용 신청 승인 분류
#
# **목표**: 범주형 데이터 인코딩
# **데이터**: Credit Approval
# **소요시간**: 2주

# %% [markdown]
# ## 1. 환경 설정
# 필요한 라이브러리와 데이터를 준비합니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print('프로젝트 환경 준비 완료')
