# %% [markdown]
# # Plant Care Reminder
#
# ## Web Development

# %% [markdown]
# ## Learning Objectives
# - Understand concepts
# - Implement solution
# - Test thoroughly

# %%
# Setup and imports
pass

# %% [markdown]
# ## Implementation
# Add your code below.

# %%
# Your implementation
pass
