# %% [markdown]
# # 28: 특성 스케일링 (Feature Scaling & Normalization)
#
# ## 주제
# 표준화, 정규화, 아웃라이어 처리
#
# ## 학습 목표
# - 개념 이해
# - 실전 적용
# - 심화 학습

# %%
# 필요한 라이브러리 import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print('모듈 28 시작')
print('주제: 표준화, 정규화, 아웃라이어 처리')

# %% [markdown]
# ## 1. 이론
#
# ### 개념
# 표준화, 정규화, 아웃라이어 처리를 학습합니다.
#
# ### 주요 공식
# - 공식 1
# - 공식 2

# %% [markdown]
# ## 2. 실습
#
# ### 예제 1
# 기본 예제를 구현합니다.

# %%
# 예제 코드
# TODO: 실제 구현 추가

# %% [markdown]
# ## 3. 연습 문제
#
# 아래 문제를 풀어보세요:
# 1. 문제 1
# 2. 문제 2
# 3. 문제 3
